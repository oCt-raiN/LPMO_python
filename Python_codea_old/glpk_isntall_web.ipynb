# %%
# !gcc --version
# Out:
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !wget ftp://ftp.gnu.org/gnu/glpk/glpk-4.65.tar.gz
# !wget ftp://ftp.gnu.org/gnu/glpk/glpk-4.65.tar.gz.sig
# Out:
# --2022-10-29 03:05:14--  ftp://ftp.gnu.org/gnu/glpk/glpk-4.65.tar.gz
#            => ‘glpk-4.65.tar.gz’
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /gnu/glpk ... done.
# ==> SIZE glpk-4.65.tar.gz ... 4167110
# ==> PASV ... done.    ==> RETR glpk-4.65.tar.gz ... done.
# Length: 4167110 (4.0M) (unauthoritative)
#
# glpk-4.65.tar.gz    100%[===================>]   3.97M  26.5MB/s    in 0.2s
#
# 2022-10-29 03:05:14 (26.5 MB/s) - ‘glpk-4.65.tar.gz’ saved [4167110]
#
# --2022-10-29 03:05:14--  ftp://ftp.gnu.org/gnu/glpk/glpk-4.65.tar.gz.sig
#            => ‘glpk-4.65.tar.gz.sig’
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:21... connected.
# Logging in as anonymous ... Logged in!
# ...

# %%
# !gpg --verify glpk-4.65.tar.gz.sig glpk-4.65.tar.gz
# Out:
# gpg: directory '/root/.gnupg' created
# gpg: keybox '/root/.gnupg/pubring.kbx' created
# gpg: Signature made Fri 16 Feb 2018 09:05:24 AM UTC
# gpg:                using DSA key D17BF2305981E818
# gpg: Can't check signature: No public key

# %%
# !gpg --recv-keys 5981E818
# Out:
# gpg: keyserver receive failed: Server indicated a failure

# %%
# !tar -xzvf glpk-4.65.tar.gz
# Out:
# glpk-4.65/
# glpk-4.65/aclocal.m4
# glpk-4.65/AUTHORS
# glpk-4.65/autogen.sh
# glpk-4.65/ChangeLog
# glpk-4.65/config.guess
# glpk-4.65/config.h.in
# glpk-4.65/config.sub
# glpk-4.65/configure
# glpk-4.65/configure.ac
# glpk-4.65/COPYING
# glpk-4.65/depcomp
# glpk-4.65/doc/
# glpk-4.65/doc/cnfsat.pdf
# glpk-4.65/doc/cnfsat.tex
# glpk-4.65/doc/glpk.pdf
# glpk-4.65/doc/glpk.tex
# glpk-4.65/doc/glpk01.tex
# glpk-4.65/doc/glpk02.tex
# glpk-4.65/doc/glpk03.tex
# glpk-4.65/doc/glpk04.tex
# glpk-4.65/doc/glpk05.tex
# glpk-4.65/doc/glpk06.tex
# glpk-4.65/doc/glpk07.tex
# glpk-4.65/doc/glpk08.tex
# glpk-4.65/doc/glpk09.tex
# glpk-4.65/doc/glpk10.tex
# glpk-4.65/doc/glpk11.tex
# glpk-4.65/doc/glpk12.tex
# glpk-4.65/doc/gmpl.pdf
# glpk-4.65/doc/gmpl.tex
# glpk-4.65/doc/gmpl_es.pdf
# glpk-4.65/doc/gmpl_es.tex
# glpk-4.65/doc/gmpl_pt-BR.pdf
# glpk-4.65/doc/gmpl_pt-BR.tex
# glpk-4.65/doc/graphs.pdf
# glpk-4.65/doc/graphs.tex
# glpk-4.65/doc/miplib2.txt
# glpk-4.65/doc/miplib3.txt
# ...

# %%
! /content/glpk-4.65/./configure
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking how to print strings... printf
# ...

# %%
# !make install
# Out:
# Making install in src
# make[1]: Entering directory '/content/src'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I/content/glpk-4.65/./src -I..  -I/content/glpk-4.65/./src -I/content/glpk-4.65/./src/amd -I/content/glpk-4.65/./src/api -I/content/glpk-4.65/./src/bflib -I/content/glpk-4.65/./src/colamd -I/content/glpk-4.65/./src/draft -I/content/glpk-4.65/./src/env -I/content/glpk-4.65/./src/intopt -I/content/glpk-4.65/./src/minisat -I/content/glpk-4.65/./src/misc -I/content/glpk-4.65/./src/mpl -I/content/glpk-4.65/./src/npp -I/content/glpk-4.65/./src/proxy -I/content/glpk-4.65/./src/simplex -I/content/glpk-4.65/./src/zlib   -g -O2 -MT libglpk_la-amd_1.lo -MD -MP -MF .deps/libglpk_la-amd_1.Tpo -c -o libglpk_la-amd_1.lo `test -f 'amd/amd_1.c' || echo '/content/glpk-4.65/./src/'`amd/amd_1.c
# ...

# %%
# !pip install pulp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 14.2 MB 23.7 MB/s
# ...

# %%
from pulp import *

x = LpVariable("x", 0, 3)
y = LpVariable("y", 0, 1)
prob = LpProblem("myProblem", LpMinimize)
prob += x + y <= 2
prob += -4*x + y

# %%
status = prob.solve()

# %%
prob
# Out:
# myProblem:
# MINIMIZE
# -4*x + 1*y + 0
# SUBJECT TO
# _C1: x + y <= 2
#
# VARIABLES
# x <= 3 Continuous
# y <= 1 Continuous

# %%
# !glpsol --version
# Out:
# glpsol: error while loading shared libraries: libglpk.so.40: cannot open shared object file: No such file or directory
