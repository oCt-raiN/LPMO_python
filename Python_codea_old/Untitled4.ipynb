# %%
def base_pairs(x,y):
  return (x=='a' and y=='u' or
      x=='u' and y=='a' or
      x=='c' and y=='g' or
      x=='g' and y=='c' or
      x=='g' and y=='u' or
      x=='u' and y=='g' )

rna.input("Enter rna seq:")
n = len(rna)

def opt(x,y):
    for i in range(x,y-5):
        j = i+4
        if base_pairs(rna[i],rna[j])==1:
            print( i,j)
            a = i
            b = j
            if b-a > 3:
                if base_pairs(a+1,b-1)==1:
                    print (a+1,b-1)
                    a = a+1
                    b = b-1
        else:
            j=j+1
