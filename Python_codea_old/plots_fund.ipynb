# %%
num = [2,3,4,5,1,1,2,7,3,6,8,3,10,12,14,16,7,9,20,16,15,15,14,20,21,22,24,3,3,4,6,1,3,1,2,1,2,3,4,5,1,1,2,7,3,6,8,3,10,12]

# %%
import matplotlib.pyplot as plt

# %%
bins = [0,5,10,15,20,25]
plt.hist(num, bins=bins, edgecolor='black')
# Out:
# (array([24., 11.,  6.,  4.,  5.]),
#  array([ 0,  5, 10, 15, 20, 25]),
#  <BarContainer object of 5 artists>)

# %%
count = 0
for i in num:
  if i<5:
    count+=1

print(count)
# Out:
# 24

# %%
import statistics
a=[10,23,22,49,65,74,32,22,21,27,28,29,34,23,33,31,32,31,32,21,46,75,50,44,32,12,80]
print(statistics.stdev([10,23,22,49,65,74,32,22,21,27,28,29,34,23,33,31,32,31,32,21,46,75,50,44,32,12,80]))
# Out:
# 18.62862423867208

# %%
sum(a)
# Out:
# 978

# %%
l=[13,15,16,16,19,20,20,21,22,22,22,22,22,22,25,25,25,25,25,25,25,30,80,90,33,34,33,34,33,34,33,34,36,40,51,53,60]

# %%
l.sort()

# %%
l
# Out:
# [13,
#  15,
#  16,
#  16,
#  19,
#  20,
#  20,
#  21,
#  22,
#  22,
#  22,
#  22,
#  22,
#  22,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  30,
#  33,
#  33,
#  33,
#  33,
#  34,
#  34,
#  34,
#  34,
#  36,
#  40,
#  51,
#  53,
#  60,
#  80,
#  90]

# %%
import numpy as np

# %%
l = np.array(l)

# %%
l = l[(l>np.quantile(l,0.1)) & (l<np.quantile(l,0.9))].tolist()

# %%
print(l)
# Out:
# [19, 20, 20, 21, 22, 22, 22, 22, 22, 22, 25, 25, 25, 25, 25, 25, 25, 30, 33, 33, 33, 33, 34, 34, 34, 34, 36, 40, 51]

# %%
import numpy as np
 
# initializing points in
# numpy arrays
point1 = np.array((2, 0))
point2 = np.array((4, 5))
 
# subtracting vector
temp = point1 - point2
 
# doing dot product
# for finding
# sum of the squares
sum_sq = np.dot(temp.T, temp)
 
# Doing squareroot and
# printing Euclidean distance
print(np.sqrt(sum_sq))
# Out:
# 5.385164807134504

# %%
print(np.sqrt(sum_sq))

# %%
# Python3 program to find Minkowski distance
 
# import math library
from math import *
from decimal import Decimal
 
# Function distance between two points
# and calculate distance value to given
# root value(p is root value)
def p_root(value, root):
     
    root_value = 1 / float(root)
    return round (Decimal(value) **
             Decimal(root_value), 3)
 
def minkowski_distance(x, y, p_value):
     
    # pass the p_root function to calculate
    # all the value of vector parallelly
    return (p_root(sum(pow(abs(a-b), p_value)
            for a, b in zip(x, y)), p_value))
 
# Driver Code
vector1 = [1,2]
vector2 = [3,5]
p = 2
print(minkowski_distance(vector1, vector2, p))
# Out:
# 3.606
