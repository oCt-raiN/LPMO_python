# %%
# !pip install cobra
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.2 MB 14.9 MB/s
# ...
#      |████████████████████████████████| 147 kB 47.2 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 44.4 MB/s
# ...
#      |████████████████████████████████| 44 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 56.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 109 kB 60.8 MB/s
# ...
#      |████████████████████████████████| 84 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 68 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 80 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 546 kB 68.9 MB/s
# ...

# %%
# !pip install d3flux
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 237 kB 18.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 53.1 MB/s
# ...
#   Created wheel for d3flux: filename=d3flux-0.2.7-py3-none-any.whl size=29950 sha256=e671780847bd7986f862cf7528efc4f71c5417dabf15d35a908985e64f0815b4
#   Stored in directory: /root/.cache/pip/wheels/01/af/5e/8ed040875b969eaf3248b7dc5fa37ebc6781c8424ef572f7ed
# ...
#   Created wheel for csscompressor: filename=csscompressor-0.9.5-py3-none-any.whl size=240349 sha256=a7faff64b109f4c73ba540d6eaa0359db9159a32954ea6132d5aaa4a7833fd67
#   Stored in directory: /root/.cache/pip/wheels/4d/71/0b/a541c02576f1ce5efaa72addf79fe3f5e8f93fb9d64d73c9bf
# Successfully built d3flux csscompressor
# ...

# %%
import cobra 
import d3flux as d3f
