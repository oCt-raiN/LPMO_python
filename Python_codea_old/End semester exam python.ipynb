# %%
pip install biopython
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 8.8 MB/s
# ...

# %%
#123013001'
#A.Aathi Manikandan
from Bio.PDB.PDBParser import PDBParser
parse =PDBParser(PERMISSIVE=1)#permissive to avoid issue in PDB
pdbid="6lU7"
filename="/content/6lu7.pdb"
help(PDBParser.get_structure)
#srtuct=PDBParser.get_structure(pdbid,"filename")# there is an error in getting 
#the structure (missing 1 required positional argument: 'file')
#atoms = structure.get_atoms()
#for atom in atoms:
#  	print(atom)

#name = atom.get_name() 
#get_id() 

#get_coord()

import re
while open("6lu7.pdb","r") as fh:
for line in fh:
  if re.search("^ATOM",line)
    if re.search("[A-Z]+/s[0-9]/s+[A-Z]![0-9]/sLYS",line)
      string +=line
lst=string.sort(" ")    
for i in range(:len(lst))
  print("id="str(lst[2]),"cordinates="str(lst[7],lst[8],lst[9]))
# Out:
#   File "<ipython-input-42-8b42cfeaefbf>", line 20
#     while open("6lu7.pdb","r") as fh:
#                                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# The given problem is to get the information on the given pdbid and use bio python to find all Coordinates of lysine in the file
