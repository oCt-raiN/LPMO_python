# %% [markdown]
# **Ex N0 3 : Identification of Differentially Expressed Genes from Affymatrix Data**
#
# Dr J Arunachalam
#
# SASTRA Deemed University

# %% [markdown]
# In this exercise we will identify differentially expressed genes from the GEO data 'GSE20986'. You are requested to gather further information about the experiment from the GEO page & corresponding publications. The code in this tutorial is applicable for other GEO data sets as well with minimum changes.

# %% [markdown]
# We will use the GEOparse library for parsing the GEO data

# %% [markdown]
# Install GEOparse with the following command

# %%
! pip install GEOparse
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GEOparse
#   Downloading GEOparse-2.0.3.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 18.2 MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.8/dist-packages (from GEOparse) (1.21.6)
# Requirement already satisfied: pandas>=0.17 in /usr/local/lib/python3.8/dist-packages (from GEOparse) (1.3.5)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from GEOparse) (2.23.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.8/dist-packages (from GEOparse) (4.64.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.17->GEOparse) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.17->GEOparse) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=0.17->GEOparse) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.21.0->GEOparse) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.21.0->GEOparse) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.21.0->GEOparse) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.21.0->GEOparse) (3.0.4)
# Building wheels for collected packages: GEOparse
#   Building wheel for GEOparse (setup.py) ... done
#   Created wheel for GEOparse: filename=GEOparse-2.0.3-py3-none-any.whl size=29064 sha256=647f4a708ad235ea3c37dd45a58fcdcabf07cce48f3f33244323554ed4cb2981
#   Stored in directory: /root/.cache/pip/wheels/7a/75/14/727a857e321c5e5590d7e58efe9f028d753d340cea4ee540f0
# Successfully built GEOparse
# Installing collected packages: GEOparse
# Successfully installed GEOparse-2.0.3

# %% [markdown]
# Import all necessary libraries

# %%
import GEOparse
import pandas as pd
import pylab as pl
import seaborn as sns
import numpy as np
import networkx as nx
import scipy
import json
import itertools

# %% [markdown]
# Download GEO data

# %%
gse = GEOparse.get_GEO(geo="GSE22255")
# Out:
# 13-Dec-2022 17:05:38 DEBUG utils - Directory ./ already exists. Skipping.
# DEBUG:GEOparse:Directory ./ already exists. Skipping.
# 13-Dec-2022 17:05:38 INFO GEOparse - Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22255/soft/GSE22255_family.soft.gz to ./GSE22255_family.soft.gz
# INFO:GEOparse:Downloading ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22255/soft/GSE22255_family.soft.gz to ./GSE22255_family.soft.gz
# 100%|██████████| 32.4M/32.4M [00:00<00:00, 124MB/s]
# 13-Dec-2022 17:05:39 DEBUG downloader - Size validation passed
# DEBUG:GEOparse:Size validation passed
# 13-Dec-2022 17:05:39 DEBUG downloader - Moving /tmp/tmphcs1vn36 to /content/GSE22255_family.soft.gz
# DEBUG:GEOparse:Moving /tmp/tmphcs1vn36 to /content/GSE22255_family.soft.gz
# 13-Dec-2022 17:05:39 DEBUG downloader - Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22255/soft/GSE22255_family.soft.gz
# DEBUG:GEOparse:Successfully downloaded ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE22nnn/GSE22255/soft/GSE22255_family.soft.gz
# 13-Dec-2022 17:05:39 INFO GEOparse - Parsing ./GSE22255_family.soft.gz:
# INFO:GEOparse:Parsing ./GSE22255_family.soft.gz:
# 13-Dec-2022 17:05:39 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 13-Dec-2022 17:05:39 DEBUG GEOparse - SERIES: GSE22255
# DEBUG:GEOparse:SERIES: GSE22255
# 13-Dec-2022 17:05:39 DEBUG GEOparse - PLATFORM: GPL570
# DEBUG:GEOparse:PLATFORM: GPL570
# /usr/local/lib/python3.8/dist-packages/GEOparse/GEOparse.py:545: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   table_data = parse_table_data(gpl_soft)
# 13-Dec-2022 17:05:40 DEBUG GEOparse - SAMPLE: GSM554014
# DEBUG:GEOparse:SAMPLE: GSM554014
# 13-Dec-2022 17:05:40 DEBUG GEOparse - SAMPLE: GSM554015
# DEBUG:GEOparse:SAMPLE: GSM554015
# 13-Dec-2022 17:05:40 DEBUG GEOparse - SAMPLE: GSM554016
# DEBUG:GEOparse:SAMPLE: GSM554016
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554017
# DEBUG:GEOparse:SAMPLE: GSM554017
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554018
# DEBUG:GEOparse:SAMPLE: GSM554018
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554019
# DEBUG:GEOparse:SAMPLE: GSM554019
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554020
# DEBUG:GEOparse:SAMPLE: GSM554020
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554021
# DEBUG:GEOparse:SAMPLE: GSM554021
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554022
# DEBUG:GEOparse:SAMPLE: GSM554022
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554023
# DEBUG:GEOparse:SAMPLE: GSM554023
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554024
# DEBUG:GEOparse:SAMPLE: GSM554024
# 13-Dec-2022 17:05:41 DEBUG GEOparse - SAMPLE: GSM554025
# DEBUG:GEOparse:SAMPLE: GSM554025
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554026
# DEBUG:GEOparse:SAMPLE: GSM554026
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554027
# DEBUG:GEOparse:SAMPLE: GSM554027
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554028
# DEBUG:GEOparse:SAMPLE: GSM554028
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554029
# DEBUG:GEOparse:SAMPLE: GSM554029
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554030
# DEBUG:GEOparse:SAMPLE: GSM554030
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554031
# DEBUG:GEOparse:SAMPLE: GSM554031
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554032
# DEBUG:GEOparse:SAMPLE: GSM554032
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554033
# DEBUG:GEOparse:SAMPLE: GSM554033
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554034
# DEBUG:GEOparse:SAMPLE: GSM554034
# 13-Dec-2022 17:05:42 DEBUG GEOparse - SAMPLE: GSM554035
# DEBUG:GEOparse:SAMPLE: GSM554035
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554036
# DEBUG:GEOparse:SAMPLE: GSM554036
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554037
# DEBUG:GEOparse:SAMPLE: GSM554037
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554038
# DEBUG:GEOparse:SAMPLE: GSM554038
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554039
# DEBUG:GEOparse:SAMPLE: GSM554039
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554040
# DEBUG:GEOparse:SAMPLE: GSM554040
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554041
# DEBUG:GEOparse:SAMPLE: GSM554041
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554042
# DEBUG:GEOparse:SAMPLE: GSM554042
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554043
# DEBUG:GEOparse:SAMPLE: GSM554043
# 13-Dec-2022 17:05:43 DEBUG GEOparse - SAMPLE: GSM554044
# DEBUG:GEOparse:SAMPLE: GSM554044
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554045
# DEBUG:GEOparse:SAMPLE: GSM554045
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554046
# DEBUG:GEOparse:SAMPLE: GSM554046
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554047
# DEBUG:GEOparse:SAMPLE: GSM554047
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554048
# DEBUG:GEOparse:SAMPLE: GSM554048
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554049
# DEBUG:GEOparse:SAMPLE: GSM554049
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554050
# DEBUG:GEOparse:SAMPLE: GSM554050
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554051
# DEBUG:GEOparse:SAMPLE: GSM554051
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554052
# DEBUG:GEOparse:SAMPLE: GSM554052
# 13-Dec-2022 17:05:44 DEBUG GEOparse - SAMPLE: GSM554053
# DEBUG:GEOparse:SAMPLE: GSM554053

# %%
def filter_genes(gse_obj, cut_off, log2, condition_list):
  if log2:
    pivoted_samples = gse_obj.pivot_samples('VALUE')[condition_list]
    return pivoted_samples
  else:
    pivoted_samples = np.log2(gse_obj.pivot_samples('VALUE')[condition_list])
  pivoted_samples_average = pivoted_samples.median(axis=1)
  print("Number of probes before filtering: ", len(pivoted_samples_average))
  expression_threshold = pivoted_samples_average.quantile(cut_off)
  expressed_probes = pivoted_samples_average[pivoted_samples_average >= expression_threshold]
  samples = np.log2(gse.pivot_samples("VALUE").loc[expressed_probes.keys()])
  samples = samples[condition_list]
  print("Number of probes after filtering: ", len(samples))
  return samples

# %%
def get_ttest(control_samples, post_samples):
  ttest_result = scipy.stats.ttest_ind(control_samples, post_samples, axis=1)
  ttest = pd.DataFrame({"stat": ttest_result[0], "pvalue": ttest_result[1]}, index=control_samples.index)

  return ttest

# %%
sample_ids = sorted([key for key in gse.gsms.keys()])
sample_ids
# Out:
# ['GSM554014',
#  'GSM554015',
#  'GSM554016',
#  'GSM554017',
#  'GSM554018',
#  'GSM554019',
#  'GSM554020',
#  'GSM554021',
#  'GSM554022',
#  'GSM554023',
#  'GSM554024',
#  'GSM554025',
#  'GSM554026',
#  'GSM554027',
#  'GSM554028',
#  'GSM554029',
#  'GSM554030',
#  'GSM554031',
#  'GSM554032',
#  'GSM554033',
#  'GSM554034',
#  'GSM554035',
#  'GSM554036',
#  'GSM554037',
#  'GSM554038',
#  'GSM554039',
#  'GSM554040',
#  'GSM554041',
#  'GSM554042',
#  'GSM554043',
#  'GSM554044',
#  'GSM554045',
#  'GSM554046',
#  'GSM554047',
#  'GSM554048',
#  'GSM554049',
#  'GSM554050',
#  'GSM554051',
#  'GSM554052',
#  'GSM554053']

# %%
control = sample_ids[0:20]
ischemic_stroke = sample_ids[20:]	
# choroid=sample_ids[6:9]
# huvec=sample_ids[9:12]
# #iris
# #retina
# #choroid
control
# Out:
# ['GSM554014',
#  'GSM554015',
#  'GSM554016',
#  'GSM554017',
#  'GSM554018',
#  'GSM554019',
#  'GSM554020',
#  'GSM554021',
#  'GSM554022',
#  'GSM554023',
#  'GSM554024',
#  'GSM554025',
#  'GSM554026',
#  'GSM554027',
#  'GSM554028',
#  'GSM554029',
#  'GSM554030',
#  'GSM554031',
#  'GSM554032',
#  'GSM554033']

# %%
control_samples = filter_genes(gse, 0.25, True, control)
ischemic_smaples = filter_genes(gse, 0.25, True, ischemic_stroke)

# %%
ttest_df = get_ttest(control_samples, ischemic_smaples)

# %%
ttest_df
# Out:
#                           stat    pvalue
# ID_REF
# 1007_s_at            -0.098940  0.921706
# 1053_at               1.648757  0.107442
# 117_at                1.164843  0.251343
# 121_at               -0.301076  0.764998
# 1255_g_at            -0.362737  0.718811
# ...                        ...       ...
# AFFX-r2-Ec-bioC-5_at -0.785910  0.436794
# AFFX-r2-Ec-bioD-3_at -1.172536  0.248280
# AFFX-r2-Ec-bioD-5_at -0.972928  0.336742
# AFFX-r2-P1-cre-3_at  -0.317624  0.752509
# AFFX-r2-P1-cre-5_at   0.088736  0.929757
#
# [54675 rows x 2 columns]

# %%
from statsmodels.stats import multitest

# %%
def get_FDR(ttest_df):
  corrected_pvalue = multitest.multipletests(pvals=ttest_df['pvalue'], method='bonferroni', alpha=0.05)
  print(corrected_pvalue)
  FDR = pd.DataFrame({'Rejected': corrected_pvalue[0], 'FDR': corrected_pvalue[1]}, index= ttest_df.index)

  return FDR

# %%
FDR = get_FDR(ttest_df)
# Out:
# (array([False, False, False, ..., False, False, False]), array([1., 1., 1., ..., 1., 1., 1.]), 9.381485199799755e-07, 9.144947416552355e-07)

# %%
selected = FDR.loc[FDR['FDR'] < 0.1]
selected
# Out:
#             Rejected       FDR
# ID_REF
# 1567009_at     False  0.054826

# %%
def get_selected_df(gse_obj, selected_FDR):
  pivoted_samples = gse_obj.pivot_samples('VALUE').loc[selected_FDR.index]
  return pivoted_samples

# %%
selected_df = get_selected_df(gse, selected)
selected_df
# Out:
# name        GSM554014  GSM554015  GSM554016  GSM554017  GSM554018  GSM554019  \
# ID_REF
# 1567009_at    2.99433     2.8593    3.18044    3.06269     2.8978    2.96311
#
# name        GSM554020  GSM554021  GSM554022  GSM554023  ...  GSM554044  \
# ID_REF                                                  ...
# 1567009_at    3.14702    2.91434    2.98669    2.92412  ...    3.25096
#
# name        GSM554045  GSM554046  GSM554047  GSM554048  GSM554049  GSM554050  \
# ID_REF
# 1567009_at    3.20366    3.24605    3.24617    3.33791     3.5345    3.13338
#
# name        GSM554051  GSM554052  GSM554053
# ID_REF
# 1567009_at    3.44088    3.05369    3.36339
#
# [1 rows x 40 columns]

# %%
selected_df = np.log2(selected_df)
selected_df
# Out:
# name        GSM554014  GSM554015  GSM554016  GSM554017  GSM554018  GSM554019  \
# ID_REF
# 1567009_at   1.582233   1.515662   1.669226   1.614799   1.534958   1.567112
#
# name        GSM554020  GSM554021  GSM554022  GSM554023  ...  GSM554044  \
# ID_REF                                                  ...
# 1567009_at   1.653986   1.543169   1.578548   1.548003  ...   1.700866
#
# name        GSM554045  GSM554046  GSM554047  GSM554048  GSM554049  GSM554050  \
# ID_REF
# 1567009_at   1.679721   1.698685   1.698739   1.738945   1.821506    1.64772
#
# name        GSM554051  GSM554052  GSM554053
# ID_REF
# 1567009_at   1.782778   1.610554   1.749916
#
# [1 rows x 40 columns]

# %%
def get_lfc(control_samples, post_samples):
  control_mean = control_samples.mean(axis=1)
  post_mean = post_samples.mean(axis=1)
  LFCs = pd.DataFrame({"LFC": (post_mean - control_mean).to_dict()})
  return LFCs

# %%
huvec_samples = selected_df[control]
choroid_samples = selected_df[ischemic_stroke]
LFCs = get_lfc(huvec_samples, choroid_samples)
LFCs
# Out:
#                  LFC
# 1567009_at  0.122949

# %%
def get_annotation(gene_dataframe, data_flatform, leftkey):
  gene_annotated = gene_dataframe.reset_index().merge(gse.gpls[data_flatform].table[["ID", "ENTREZ_GENE_ID", "Gene Symbol"]],
                                left_on=leftkey, right_on="ID").set_index(leftkey)
  del gene_annotated["ID"]
  # remove probes without ENTREZ
  gene_annotated = gene_annotated.dropna(subset=["ENTREZ_GENE_ID"])
  # remove probes with more than one gene assigned
  gene_annotated['ENTREZ_GENE_ID'] = pd.to_numeric(gene_annotated['ENTREZ_GENE_ID'], errors="coerce")
  gene_annotated.dropna(how="any", inplace=True)
  gene_annotated['ENTREZ_GENE_ID'] = gene_annotated.ENTREZ_GENE_ID.astype('int').astype('str')
  # for each gene average LFC over probes
  gene_annotated = gene_annotated.groupby("Gene Symbol").median()

  return gene_annotated

# %%
LFCs_annotated = get_annotation(LFCs, 'GPL570', 'index')

# %%
LFCs_annotated
# Out:
# Empty DataFrame
# Columns: [LFC]
# Index: []
