# %%
import pandas as pd
import numpy as np
dat=pd.read_excel("Acoustic_Extinguisher_Fire_Dataset.xlsx")
del dat["FUEL"]
df1=dat.loc[0:5000]
X=np.array(df1)

# %%
df1.shape
# Out:
# (17442, 6)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
import time

# %%
# k-means clustering
from numpy import unique
from numpy import where
from sklearn.cluster import KMeans
from matplotlib import pyplot
start=time.time()
# define the model
model = KMeans(n_clusters=2)
# fit the model
model=model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken for the output is",end-start)
# Out:
# The time taken for the output is 0.4241523742675781

# %%
# affinity propagation clustering
from sklearn.cluster import AffinityPropagation
from matplotlib import pyplot
start=time.time()
# define the model
model = AffinityPropagation(damping=0.7)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run Mean shift clustering alogoritm is", end-start)
# Out:
# The time taken to run Mean shift clustering alogoritm is 35.19494581222534

# %%
#Mean shift clustering
from sklearn.cluster import MeanShift
from matplotlib import pyplot
start=time.time()
# define the model
model = MeanShift()
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run Mean shift clustering alogoritm is", end-start)
# Out:
# The time taken to run Mean shift clustering alogoritm is 36.45668172836304

# %%
# spectral clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import SpectralClustering
from matplotlib import pyplot
start=time.time()
# define the model
model = SpectralClustering(n_clusters=2)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run Mean shift clustering alogoritm is", end-start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-57bd3a4605f2> in <module>()
#       9 model = SpectralClustering(n_clusters=2)
#      10 # fit model and predict clusters
# ---> 11 yhat = model.fit_predict(X)
#      12 # retrieve unique clusters
#      13 clusters = unique(yhat)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_spectral.py in fit_predict(self, X, y)
#     655             Cluster labels.
#     656         """
# --> 657         return super().fit_predict(X, y)
#     658
#     659     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_predict(self, X, y)
#     734         # non-optimized default implementation; override when a better
#     735         # method is possible for a given clustering algorithm
# --> 736         self.fit(X)
#     737         return self.labels_
#     738
#
# ...

# %%
#Hierarchical clustering: Agglomerative Clustering
from sklearn.cluster import AgglomerativeClustering
from matplotlib import pyplot
start=time.time()
# define the model
model = AgglomerativeClustering(n_clusters=2)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run Hierarchical clustering algorithm is", end-start)
# Out:
# The time taken to run Hierarchical clustering algorithm is 0.7224199771881104

# %%
#DBSCAN clustering
from sklearn.cluster import DBSCAN
from matplotlib import pyplot
start=time.time()
# define the model
model = DBSCAN(eps=0.50, min_samples=10)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("the time taken to run DBSCAN clustering algorithm is", end-start)
# Out:
# the time taken to run DBSCAN clustering algorithm is 0.27259063720703125

# %%
#OPTICS Clustering
from sklearn.cluster import OPTICS
from matplotlib import pyplot
start=time.time()
# define the model
model = OPTICS(eps=0.8, min_samples=10)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run OPTICS clustering algorithm is", end-start)
# Out:
# The time taken to run OPTICS clustering algorithm is 7.230146169662476

# %%
#Birch clustering
from sklearn.cluster import Birch
from matplotlib import pyplot
start=time.time()
# define the model
model = Birch(threshold=0.01, n_clusters=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()
end=time.time()
print("The time taken to run Birch algorithm is", end-start)
# Out:
# The time taken to run Birch algorithm is 1.5914485454559326

# %% [markdown]
# # 4. In K-Means, plot the SSE values vs k?

# %%
def drawSSEPlot(df, column_indices, n_clusters=8, max_iter=300, tol=1e-04, init='k-means++', n_init=10, algorithm='auto'):
    import matplotlib.pyplot as plt
    inertia_values = []
    for i in range(1, n_clusters+1):
        km = KMeans(n_clusters=i, max_iter=max_iter, tol=tol, init=init, n_init=n_init, random_state=1, algorithm=algorithm)
        km.fit_predict(df.iloc[:, column_indices])
        inertia_values.append(km.inertia_)
    fig, ax = plt.subplots(figsize=(8, 6))
    plt.plot(range(1, n_clusters+1), inertia_values, color='red')
    plt.xlabel('No. of Clusters', fontsize=15)
    plt.ylabel('SSE / Inertia', fontsize=15)
    plt.title('SSE / Inertia vs No. Of Clusters', fontsize=15)
    plt.grid()
    plt.show()

# %%
from sklearn.cluster import KMeans
df = pd.DataFrame(X)
drawSSEPlot(df, [0,1,2,3,4])

# %% [markdown]
# 1. How many datapoints are there in your dataset?
#
# 17442 rows, 6 coloumns
#
# 2. What was the timetaken to perform the clustering for a) to h)?
#
# a. K-means: 0.4241
#
# b. Affinity Propagation: 35.1949
#
# c. Mean Shift: 36.4566
#
# d. Spectral clustering:
#
# e. Hierarchical clustering: 0.7224
#
# f. DBSCAN: 0.27259
#
# g. OPTICS: 7.23014
#
# h. BIRCH: 1.59144
#
# 5. Which clustering method gave the best optimal number of clusters?
#
#  K-means, Mean shift clustering, Brich clustering, Agglomerative clustering.
