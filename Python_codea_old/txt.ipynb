# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/full genecon.txt",sep="\t")

# %%
df["Gene name"]
# Out:
# 0            TSPAN6
# 1              TNMD
# 2              DPM1
# 3             SCYL3
# 4          C1orf112
#             ...
# 18818           NaN
# 18819       UBA6-DT
# 18820       DPH6-DT
# 18821        BCKDHA
# 18822         INSL3
# Name: Gene name, Length: 18823, dtype: object

# %%
with open(r'Gene_name.txt', 'w') as fp:
    for item in df["Gene name"]:
        fp.write("%s\n" % item)
    print('Done')
# Out:
# Done
