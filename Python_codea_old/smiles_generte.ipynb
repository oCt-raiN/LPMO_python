# %%
import pandas as pd

df =  pd.read_csv("/content/Pubchem_69percent_16666similar_1000mols.csv")
df["isosmiles"]
df["cid"]
for i in range(0,len(df["isosmiles"])):
  f_name = str(df["cid"][i])+".smiles"
  fh = open(f_name,"w")
  fh.write(df["isosmiles"][i])
  fh.close()
# Out:
# 0           1254
# 1          16666
# 2          19100
# 3          19243
# 4          19244
#          ...
# 995    164079591
# 996    164111859
# 997    164599180
# 998    164724940
# 999    164784929
# Name: cid, Length: 1000, dtype: int64
