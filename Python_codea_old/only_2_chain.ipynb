# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
a=pd.read_csv("pdb_unique.csv")

# %%
a["pdb_id"]
# Out:
# 0        6SIF
# 1        6SIG
# 2        2BL8
# 3        1S7P
# 4        4CU4
#          ...
# 27627    6RXV
# 27628    6RXX
# 27629    6RXZ
# 27630    2DFI
# 27631    7MUQ
# Name: pdb_id, Length: 27632, dtype: object

# %%
a
# Out:
#        pep_id                                   pepdide pdb_id
# 0           6                Aureocin A53 (Bacteriocin)   6SIF
# 1           6                Aureocin A53 (Bacteriocin)   6SIG
# 2          10  Carnobacteriocin B2 (CbnB2; Bacteriocin)   2BL8
# 3          25        Microcin J25 (MccJ25; Bacteriocin)   1S7P
# 4          25        Microcin J25 (MccJ25; Bacteriocin)   4CU4
# ...       ...                                       ...    ...
# 27627    5538                                      DRIM   6RXV
# 27628    5538                                      DRIM   6RXX
# 27629    5538                                      DRIM   6RXZ
# 27630    5541                                     MAP-1   2DFI
# 27631    5541                                     MAP-1   7MUQ
#
# [27632 rows x 3 columns]

# %%
pip install pypdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
from pypdb import *  
#for i in range(0):
b=[]
q=[]
p=[]
output=[]
for n in range(0,len(a)):
  b=a['pdb_id'][n]
  c=[]
  c.append(a['pep_id'][n])
  c.append(a['pepdide'][n])
  all_info = get_info(b)
  if(all_info["rcsb_entry_info"]["deposited_polymer_entity_instance_count"]!=0):
    c.append(a['pdb_id'][n])
    p=all_info["rcsb_entry_info"]["deposited_polymer_entity_instance_count"]
    c.append(p)
    output.append(a['pdb_id'][n])
  else:
    c.append('[0]')
  q.append(c)
  df=pd.DataFrame(q,columns=["PepID","peptide","pdb_id","No_chains"])
  print(df)

# %%
df.to_csv('/content/drive/MyDrive/lab gfv/bamp/pdb..csv', mode='a', index=False, header=False)

# %%
df
# Out:
#        PepID                                   peptide pdb_id  No_chains
# 0          6                Aureocin A53 (Bacteriocin)   6SIF          8
# 1          6                Aureocin A53 (Bacteriocin)   6SIG          4
# 2         10  Carnobacteriocin B2 (CbnB2; Bacteriocin)   2BL8          3
# 3         25        Microcin J25 (MccJ25; Bacteriocin)   1S7P          2
# 4         25        Microcin J25 (MccJ25; Bacteriocin)   4CU4          2
# ...      ...                                       ...    ...        ...
# 27627   5538                                      DRIM   6RXV         68
# 27628   5538                                      DRIM   6RXX         68
# 27629   5538                                      DRIM   6RXZ         68
# 27630   5541                                     MAP-1   2DFI          2
# 27631   5541                                     MAP-1   7MUQ        205
#
# [27632 rows x 4 columns]

# %%
df.to_csv('/content/pdb.kl.csv', mode='a', index=False, header=False)
