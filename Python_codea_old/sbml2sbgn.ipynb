# %%
# !wget https://downloads.sourceforge.net/project/sbfc/sbfc/sbfc-1.3.7.zip?ts=gAAAAABjkNfbp3OTNlLKy1qCOqG-WT9Tr-N_5MIKoGuZUy-iDnWsieI8U8tt1bfkd2YOMRUpC_FjUL_v-NRy-izovRcgO7iUaw%3D%3D&r=https%3A%2F%2Fsourceforge.net%2Fprojects%2Fsbfc%2Ffiles%2Fsbfc%2Fsbfc-1.3.7.zip%2Fdownload
# Out:
# --2022-12-07 18:14:05--  https://downloads.sourceforge.net/project/sbfc/sbfc/sbfc-1.3.7.zip?ts=gAAAAABjkNfbp3OTNlLKy1qCOqG-WT9Tr-N_5MIKoGuZUy-iDnWsieI8U8tt1bfkd2YOMRUpC_FjUL_v-NRy-izovRcgO7iUaw%3D%3D
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Connecting to downloads.sourceforge.net (downloads.sourceforge.net)|204.68.111.105|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://phoenixnap.dl.sourceforge.net/project/sbfc/sbfc/sbfc-1.3.7.zip [following]
# --2022-12-07 18:14:06--  https://phoenixnap.dl.sourceforge.net/project/sbfc/sbfc/sbfc-1.3.7.zip
# Resolving phoenixnap.dl.sourceforge.net (phoenixnap.dl.sourceforge.net)... 184.164.141.26
# Connecting to phoenixnap.dl.sourceforge.net (phoenixnap.dl.sourceforge.net)|184.164.141.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44116876 (42M) [application/octet-stream]
# ...

# %%
# !git clone https://github.com/NRNB-GSoC2017-SBML2SBGNML-Converters/SBML2SBGNML
# Out:
# Cloning into 'SBML2SBGNML'...
# remote: Enumerating objects: 2291, done.
# remote: Total 2291 (delta 0), reused 0 (delta 0), pack-reused 2291
# Receiving objects: 100% (2291/2291), 73.38 MiB | 32.19 MiB/s, done.
# Resolving deltas: 100% (1286/1286), done.

# %%
# !pwd
# Out:
# /content

# %%
# !./SBML2SBGNML/code/sbml2sbgnml.sh
# Out:
# Usage:
#     To convert a given file(s) of a specific model type using a provided converter
#        /content/SBML2SBGNML/code/sbfConverter.sh InputModelType ConverterName [file | folder]
#
#     For instance, to convert an SBML file to XPP :
#        /content/SBML2SBGNML/code/sbfConverter.sh SBMLModel SBML2XPP [file.xml | folder]
#
#     For retrieving the complete lists of the available models and converters, type the commands
#        ./sbfModelList.sh
#        ./sbfConverterList.sh

# %%
# !./SBML2SBGNML/code/sbfModelList.sh
# Out:
# APMModel
# DotModel
# OctaveModel
# SBGNMLStringModel
# SBMLModel
# XPPModel

# %%
# !./SBML2SBGNML/code/sbfConverterList.sh
# Out:
# Loading the default Identifiers.org registry database from the jar file.
# Error encountered while attempting to load libSBML:
# Please check the value of your LD_LIBRARY_PATH environment variable and/or your 'java.library.path' system property (depending on which one you are using) to make sure it list the directories needed to find the libsbmlj.so library file and libraries it depends upon (e.g., the XML parser).

# %%
import re

def use_regex(input_text):
    pattern = re.compile(r"lda;kfjasp'f ]\[f kj \.,\[ F M\[ASK NAS\[A] NSA APF =NK FA\[  NA Q,DSASKL NS AFSDNFSKJFJKSAbebdfabfjkb JSDAFAS FSAJFSAB A POI psd kaafnasl \.dfasdfa fsadf da f")
    return pattern

# %%
a = use_regex("asdhdgjhagfja DA")
print(a)
# Out:
# re.compile("lda;kfjasp'f ]\\[f kj \\.,\\[ F M\\[ASK NAS\\[A] NSA APF =NK FA\\[  NA Q,DSASKL NS AFSDNFSKJFJKSAbebdfabfjkb JSDAFAS FSAJFSAB A POI psd kaafnasl \\.dfasdfa fsadf da f")

# %%
a = re.compile("JSAG DSAfsda dsasdfa  FA fs ")

# %%
a
# Out:
# re.compile(r'JSAG DSAfsda dsasdfa  FA fs ', re.UNICODE)
