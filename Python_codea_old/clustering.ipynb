# %%
# install the required packages
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
BiocManager::install("golubEsets")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# '?repositories' for details
#
# replacement repositories:
#     CRAN: https://cran.rstudio.com
#
#
# Bioconductor version 3.16 (BiocManager 1.30.19), R 4.2.2 Patched (2022-11-10
#   r83330)
#
# Installing package(s) 'BiocVersion', 'golubEsets'
#
# also installing the dependencies ‘BiocGenerics’, ‘Biobase’
#
#
# Old packages: 'bit', 'data.table', 'devtools', 'knitr', 'pkgload', 'sass',
#   'tidyverse', 'vctrs', 'xfun', 'foreign'
