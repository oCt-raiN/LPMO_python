# %%
# !sudo apt-cache search "glpk"
# Out:
# glpk-doc - linear programming kit - documentation files
# glpk-utils - linear programming kit - utility files
# libglpk-dev - linear programming kit - development files
# libglpk-java - Java binding to the GNU Linear Programming Kit
# libglpk40 - linear programming kit with integer (MIP) support
# python-swiglpk - Plain Python bindings for the GNU Linear Programming Kit (Python 2)
# python3-swiglpk - Plain Python bindings for the GNU Linear Programming Kit (Python 3)
# r-cran-glpkapi - GNU R package "R Interface to C API of GLPK"
# r-cran-rglpk - GNU R package "R/GNU Linear Programming Kit Interface"
# r-cran-roi.plugin.glpk - GNU R package "'ROI' Plug-in 'GLPK'"

# %%
# !pip install PyFBA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.5 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 154 kB 67.8 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 40.7 MB/s
# ...
#      |████████████████████████████████| 153 kB 54.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 120 kB 53.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 56.3 MB/s
# ...
#      |████████████████████████████████| 82 kB 812 kB/s
# ...
#   Created wheel for PyFBA: filename=PyFBA-2.62-py3-none-any.whl size=12621390 sha256=5316ed25fe4f83628f9c5e5f30977e2443951d95a3c3c3abf02cbbe65436cf19
#   Stored in directory: /root/.cache/pip/wheels/f2/da/62/10034dbff5069f4af4a9e4941bd664776cedcbd3d06ca8f6d7
# ...
#   ERROR: Failed building wheel for glpk
# Successfully built PyFBA
# Failed to build glpk
# ...

# %%
! cd /content/drive/MyDrive/OptFlux

# %% [markdown]
# Optflux

# %%
# !wget https://downloads.sourceforge.net/project/optflux/LatestRelease/OptFlux-3.4.0-linux-x64-installer.run?ts=gAAAAABi_yhXoaeQkJqLqGTXmIEi-rJIrL3gu8J365InpmH6ZP6S-PmRfjrHep2GYUZ-N7W8hFv5SvCy5QQVW_bN5vY2izgt2g%3D%3D&r=https%3A%2F%2Fsourceforge.net%2Fprojects%2Foptflux%2Ffiles%2FLatestRelease%2FOptFlux-3.4.0-linux-x64-installer.run%2Fdownload
# Out:
# --2022-08-27 17:12:50--  https://downloads.sourceforge.net/project/optflux/LatestRelease/OptFlux-3.4.0-linux-x64-installer.run?ts=gAAAAABi_yhXoaeQkJqLqGTXmIEi-rJIrL3gu8J365InpmH6ZP6S-PmRfjrHep2GYUZ-N7W8hFv5SvCy5QQVW_bN5vY2izgt2g%3D%3D
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Connecting to downloads.sourceforge.net (downloads.sourceforge.net)|204.68.111.105|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://master.dl.sourceforge.net/project/optflux/LatestRelease/OptFlux-3.4.0-linux-x64-installer.run?viasf=1 [following]
# --2022-08-27 17:12:50--  https://master.dl.sourceforge.net/project/optflux/LatestRelease/OptFlux-3.4.0-linux-x64-installer.run?viasf=1
# Resolving master.dl.sourceforge.net (master.dl.sourceforge.net)... 216.105.38.12
# Connecting to master.dl.sourceforge.net (master.dl.sourceforge.net)|216.105.38.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
! ./OptFlux-3.4.0-linux-x64-installer.run
# Out:
# /bin/bash: ./OptFlux-3.4.0-linux-x64-installer.run: No such file or directory

# %% [markdown]
# GEMSiRV

# %%
! wget  http://sb.nhri.org.tw/GEMSiRV/upload/2016/4/GEMSiRV-18051228.tar
# Out:
# --2022-08-18 07:03:56--  http://sb.nhri.org.tw/GEMSiRV/upload/2016/4/GEMSiRV-18051228.tar
# Resolving sb.nhri.org.tw (sb.nhri.org.tw)... 211.76.174.216
# Connecting to sb.nhri.org.tw (sb.nhri.org.tw)|211.76.174.216|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9314304 (8.9M) [application/x-tar]
# Saving to: ‘GEMSiRV-18051228.tar’
#
# GEMSiRV-18051228.ta 100%[===================>]   8.88M   980KB/s    in 17s
#
# 2022-08-18 07:04:14 (543 KB/s) - ‘GEMSiRV-18051228.tar’ saved [9314304/9314304]

# %%
import tarfile
my_tar = tarfile.open('pathwayanalyser-1.0.tar.gz')
my_tar.extractall('./my_folder') # specify which folder to extract to
my_tar.close()

# %%
# !sh /content/my_folder/pathwayanalyser-1.0/install.sh
# Out:
# sh: 0: Can't open /content/my_folder/pathwayanalyser-1.0/install.sh
