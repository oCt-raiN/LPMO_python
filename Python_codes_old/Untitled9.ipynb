# %%
n=int(input())
x=n%2
if  x==1:
  print("Weird")
elif n<5 and 2<n:
  print ("Not Weird")
elif 6<n and  20>n:
  print("Weird")
elif n>20:
  print("Not Weird")
# Out:
# 5
# Weird

# %%
n=input()
if int(n%2)==0:
  {print("even")
  }
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cd2c643d84e4> in <module>()
#       1 n=input()
# ----> 2 if int(n%2)==0:
#       3   {print("even")
#       4   }
#
# TypeError: not all arguments converted during string formatting

# %%
n=1090%2
print(n)
# Out:
# 0
