# %%
  #1
  L=["python","is","an","amazing","language"]
  L1=["programing"]
  print (L+L1)
  #2
  #usingL
  L2=['I','miss','SASTRA','canteen','gossip']
  L=L+L2
  print(L)
  #3
  #4
  N=[55,6,777,54,6,76,101,1,6,2,6]
  a=max(N)
  b=min(N)
  print ("The maximum of the list N",a)
  print ("The minimum of the list N",b)
  #5
  print (54 in N)
  #6
  L3=[55,6,777,54,6,76,-101,1,-6,-2,6]
  
  #8
  seq="..."
# Out:
# ['python', 'is', 'an', 'amazing', 'language', 'programing']
# ['python', 'is', 'an', 'amazing', 'language', 'I', 'miss', 'SASTRA', 'canteen', 'gossip']
# The maximum of the list N 777
# The minimum of the list N 1
# True
