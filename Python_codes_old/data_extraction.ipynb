# %%
# !wget https://reactome.org/ContentService/exporter/event/R-HSA-70171.sbml
# Out:
# --2022-10-12 07:01:40--  https://reactome.org/ContentService/exporter/event/R-HSA-70171.sbml
# Resolving reactome.org (reactome.org)... 100.25.71.177
# Connecting to reactome.org (reactome.org)|100.25.71.177|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: unspecified [application/sbml+xml]
# Saving to: ‘R-HSA-70171.sbml’
#
# R-HSA-70171.sbml        [ <=>                ] 224.90K  --.-KB/s    in 0.07s
#
# 2022-10-12 07:01:40 (2.97 MB/s) - ‘R-HSA-70171.sbml’ saved [230301]

# %%
fh = open("R-HSA-70171.sbml","r")

# %%
for line in fh:
  print(line)
# Out:
# Streaming output truncated to the last 5000 lines.
#         <annotation>
#
#           <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#" xmlns:bqbiol="http://biomodels.net/biology-qualifiers/">
#
#             <rdf:Description rdf:about="#metaid_46">
#
#               <bqbiol:is>
#
#                 <rdf:Bag>
#
#                   <rdf:li rdf:resource="https://identifiers.org/CHEBI:30616" />
#
#                   <rdf:li rdf:resource="https://identifiers.org/reactome:R-ALL-113592" />
#
#                 </rdf:Bag>
#
#               </bqbiol:is>
#
#             </rdf:Description>
#
#           </rdf:RDF>
#
#         </annotation>
#
#       </species>
#
#       <species boundaryCondition="false" compartment="compartment_70101" constant="false" hasOnlySubstanceUnits="false" id="species_8955759" metaid="metaid_47" name="G1,6BP [cytosol]" sboTerm="SBO:0000247">
#
#         <notes>
#
# ...

# %%
# %%perl
#
# open f1,"R-HSA-70171.sbml";
#
# foreach $x(<f1>)
# {
#     $x=~s/[\"]/g;
# }
