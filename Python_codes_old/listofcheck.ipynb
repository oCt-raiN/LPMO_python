# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
a=pd.read_csv("pdb.csv")

# %%
#for i in range(0):
b=[]
q=[]
p=[]
output=[]
for n in range(0,len(a)):
  b=a['pdb_id'][n].split("'")
  for i in b:
    c=[]
    c.append(a['pep_id'][n])
    c.append(a['peptide'][n])
    if(len(i)==4):
      if i not in output:
        c.append(i)
        output.append(i)
        q.append(c)
        df=pd.DataFrame(q,columns=["PepID","peptide","pdb_id"])

# %%
df.to_csv('/content/drive/MyDrive/lab gfv/bamp/pdb_unique.csv', mode='a', index=False, header=False)

# %%
with open('result.txt', 'w') as fp:
    for item in l:
        # write each item on a new line
        fp.write("%s\n" % item)
print('Done')
