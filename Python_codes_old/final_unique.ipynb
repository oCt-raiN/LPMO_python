# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
a=pd.read_csv("/content/drive/MyDrive/lab gfv/bamp/bapm_retreive_merged.csv")

# %%
a
# Out:
#       pep_id                                     peptide pdb_id  \
# 0         25          Microcin J25 (MccJ25; Bacteriocin)   1S7P
# 1         25          Microcin J25 (MccJ25; Bacteriocin)   4CU4
# 2         28            Plantazolicin (PZN; Bacteriocin)   5DM0
# 3         33  Snakin-1 (StSN1; Cys-rich; Plant defensin)   5E5Q
# 4        682                           Gramicidin S (GS)   5ISX
# ...      ...                                         ...    ...
# 1815    5493                peptide 13 (Derived from B1)   7TBT
# 1816    5494                peptide 14 (Derived from B1)   2Z4J
# 1817    5496                peptide 16 (Derived from B1)   5KWN
# 1818    5498                peptide 18 (Derived from B1)   5JZ8
# 1819    5498                peptide 18 (Derived from B1)   5JZU
#
#                                                   title
# 0     Solution structure of thermolysin digested mic...
# 1     FhuA from E. coli in complex with the lasso pe...
# ...

# %%
a['pdb_id'][2]
# Out:
# '5DM0'

# %%
b=[]
q=[]
p=[]
output=[]
for i in range(0,len(a)):
  if a['pdb_id'][i] not in output:
    c=[]
    c.append(a['pep_id'][i])
    c.append(a['peptide'][i])
    c.append(a['pdb_id'][i])
    c.append(a['title'][i])
    q.append(c)
    df=pd.DataFrame(q,columns=["PepID","peptide","pdb_id","title"])
    output.append(a['pdb_id'][i])

# %%
df.to_csv("data_B_amp.csv")

# %%
df
# Out:
#      PepID                                            peptide pdb_id  \
# 0       25                 Microcin J25 (MccJ25; Bacteriocin)   1S7P
# 1       25                 Microcin J25 (MccJ25; Bacteriocin)   4CU4
# 2       28                   Plantazolicin (PZN; Bacteriocin)   5DM0
# 3       33         Snakin-1 (StSN1; Cys-rich; Plant defensin)   5E5Q
# 4      682                                  Gramicidin S (GS)   5ISX
# ..     ...                                                ...    ...
# 727    980  G2 (Bac2A variant through single amino acid su...   4LAD
# 728    982  R3 (Bac2A variant through single amino acid su...   3W2W
# 729    982  R3 (Bac2A variant through single amino acid su...   4H4K
# 730   3191                       Peptide C (Insects, animals)   1P4N
# 731   3191                       Peptide C (Insects, animals)   3GKR
#
#                                                  title
# 0    Solution structure of thermolysin digested mic...
# ...
