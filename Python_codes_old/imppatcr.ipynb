# %%
fh = open("piper_nigurm.txt")
f1 = fh.readlines()
len(f1)
# Out:
# 509

# %%
l=[]
for i in  f1:
  a= i.split("\t")
  l.append(a[3])

# %%
len(l)
# Out:
# 509

# %%
f1 = open("pytochemical.txt","a")
for i in l:
  f1.write(i)
  f1.write("\n")
