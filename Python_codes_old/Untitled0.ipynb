# %%
iupac={'A':'ALA','C':'CYS','G':'GLY'}
print('c strands for aa {0}'.format(iupac['C']))
print(iupac.values('A'))
# Out:
# c strands for aa CYS
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-4b13816e4e62> in <module>()
#       1 iupac={'A':'ALA','C':'CYS','G':'GLY'}
#       2 print('c strands for aa {0}'.format(iupac['C']))
# ----> 3 print(iupac.values('A'))
#
# TypeError: values() takes no arguments (1 given)
