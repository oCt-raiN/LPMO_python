# %%
# !npm install -g github-files-fetcher
# Out:
# /tools/node/bin/fetcher -> /tools/node/lib/node_modules/github-files-fetcher/index.js
# /tools/node/bin/github-files-fetcher -> /tools/node/lib/node_modules/github-files-fetcher/index.js
# + github-files-fetcher@1.6.0
# added 1 package from 1 contributor in 1.667s

# %%
# !fetcher --url="https://github.com/shashank-ravichandran/B-AMP/tree/master/static/peptides/pdb"  --out=/tmp
# Out:
# 7fetcher |░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░| 0% || 0/0 File(s) || downloading... || authenticated: falsefetcher |░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░| 0% || 0/1000 File(s) || downloading... || authenticated: false(node:638) [DEP0066] DeprecationWarning: OutgoingMessage.prototype._headers is deprecated
# (Use `node --trace-deprecation ...` to show where the warning was created)
# fetcher |░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░| 0% || 1/1000 File(s) || downloading... || authenticated: falsefetcher |███████████████████░░░░░░░░░░░░░░░░░░░░░| 48% || 483/1000 File(s) || downloading... || authenticated: falsefetcher |████████████████████████████████░░░░░░░░| 80% || 807/1000 File(s) || downloading... || authenticated: falsefetcher |████████████████████████████████████████| 100% || 1000/1000 File(s) || downloaded || authenticated: false8
